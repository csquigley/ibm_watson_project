# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr = np.random.randint(0,101,(1,20))
noise = 25*np.random.rand(1,20)
y = 2*arr + 7 + noise

# %%
plt.scatter(arr,y)
plt.title('A random plot of random points')
plt.show()

# %%
# Out:
# 0.5379614808357261
